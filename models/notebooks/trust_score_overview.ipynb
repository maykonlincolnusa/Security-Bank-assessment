# %% [markdown]
# # Trust Score Modeling Overview
#
# Este notebook documenta o fluxo de modelagem para o Trust Score.
# - Features: solidez financeira, estabilidade, sinais regulatorios, sinais externos e seguranca.
# - Modelos: baseline (logreg, random forest, XGBoost) e opcoes avancadas.

# %%
from models.synthetic import generate_synthetic_dataset
from models.train_baselines import train_baselines

df = generate_synthetic_dataset(rows=300)
results, metrics_path, model_path = train_baselines(df, target_col='trust_label', output_dir='models/output')
results

# %% [markdown]
# ## Interpretacao
# Use o relatorio HTML gerado em `models/output/report.html` para revisar metricas e importancia de features.
